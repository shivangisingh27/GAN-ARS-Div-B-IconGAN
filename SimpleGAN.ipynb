# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import pandas as pd
from PIL import Image
import io

# Load the dataset from Parquet file
df = pd.read_parquet('train-00000-of-00001-b64601da56687a05.parquet')

# Shorten the dataset to 800 images and corresponding text entries
shortened_df = df.head(800)
noise_dim=100

epochs = 100
batch_size = 32

# Preprocess the images
def preprocess_image(image_bytes):
    image = Image.open(io.BytesIO(image_bytes['bytes']))  # Open image from bytes
    image = image.convert('RGB')  # Convert to RGB format if necessary
    image = image.resize((64, 64))  # Resize image
    image = np.array(image)  # Convert PIL image to numpy array
    image = image.astype(np.float32) / 255.0  # Convert pixel values to [0, 1]
    return image

# Convert image bytes to numpy arrays
images = np.array([preprocess_image(image) for image in shortened_df['image']])

# Define the Generator network
def build_generator(noise_dim):
    input_noise = layers.Input(shape=(noise_dim,))

    # Noise dense layer
    noise_dense = layers.Dense(256)(input_noise)

    # Generator layers
    x = layers.Dense(256 * 8 * 8, activation='relu')(noise_dense)
    x = layers.Reshape((8, 8, 256))(x)
    x = layers.Conv2DTranspose(128, kernel_size=5, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2DTranspose(64, kernel_size=5, strides=2, padding='same', activation='relu')(x)
    generator_output = layers.Conv2DTranspose(3, kernel_size=5, strides=2, padding='same', activation='sigmoid')(x)

    generator_model = models.Model(inputs=[input_noise], outputs=generator_output)

    return generator_model

# Define the Discriminator network
def build_discriminator():
    input_image = layers.Input(shape=(64, 64, 3))
    # Image embedding layers
    x = layers.Conv2D(64, kernel_size=5, strides=2, padding='same', activation='relu')(input_image)
    x = layers.Conv2D(128, kernel_size=5, strides=2, padding='same', activation='relu')(x)
    image_embedding = layers.Flatten()(x)

    # Discriminator layers
    x = layers.Dense(256, activation='relu')(image_embedding)
    discriminator_output = layers.Dense(1, activation='sigmoid')(x)

    discriminator_model = models.Model(inputs=[input_image], outputs=discriminator_output)

    return discriminator_model

# Define the conditional gan model
def build_gan(generator, discriminator):
    input_noise = layers.Input(shape=(noise_dim,))

    fake_image = generator([input_noise])
    validity = discriminator([fake_image])

    cgan = models.Model(inputs=[input_noise], outputs=validity)

    return cgan

# Instantiate the models
generator = build_generator(noise_dim)
discriminator = build_discriminator()
gan = build_gan(generator, discriminator)

# Compile the models
discriminator.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
gan.compile(optimizer='adam', loss='binary_crossentropy')

import matplotlib.pyplot as plt

# Train the GAN models
def train_gan(generator, discriminator, gan, images, noise_dim, epochs=10, batch_size=32):
    discriminator_losses = []
    generator_losses = []

    for epoch in range(epochs):
        for batch_start in range(0, len(images), batch_size):
            # Generate noise
            noise = np.random.normal(0, 1, (batch_size, noise_dim))

            # Select a random batch of images and text embeddings
            real_images_batch = images[batch_start:batch_start+batch_size]

            # Generate fake images from noise and text embeddings
            generated_images = generator.predict([noise])

            # Train the Discriminator
            discriminator_loss_real = discriminator.train_on_batch([real_images_batch], np.ones((batch_size, 1)))
            discriminator_loss_fake = discriminator.train_on_batch([generated_images], np.zeros((batch_size, 1)))
            discriminator_loss = 0.5 * np.add(discriminator_loss_real, discriminator_loss_fake)

            # Train the Generator (via cGAN)
            noise = np.random.normal(0, 1, (batch_size, noise_dim))  # Generate new noise for training Generator
            gan_loss = gan.train_on_batch([noise], np.ones((batch_size, 1)))

            # Store losses
            discriminator_losses.append(discriminator_loss[0])
            generator_losses.append(gan_loss)

            # Print training progress
            print(f"Epoch {epoch+1}/{epochs}, Batch {batch_start//batch_size+1}/{len(images)//batch_size}, Discriminator Loss: {discriminator_loss[0]}, Generator Loss: {gan_loss}")

    # Plot Losses
    plt.plot(discriminator_losses, label='Discriminator Loss')
    plt.plot(generator_losses, label='Generator Loss')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.title('GAN Training Loss')
    plt.legend()
    plt.savefig('loss_plot.pdf')
    plt.show()

    # Save models
    generator.save('generator_model.h5')
    discriminator.save('discriminator_model.h5')
    gan.save('gan_model.h5')

    # Generate sample images
    sample_noise = np.random.normal(0, 1, (3, noise_dim))
    generated_samples = generator.predict(sample_noise)

    # Plot and save sample images
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))
    for i, ax in enumerate(axes):
        ax.imshow(generated_samples[i])
        ax.axis('off')
    plt.savefig('sample_images.pdf')
    plt.show()

# Train the GAN models
train_gan(generator, discriminator, gan, images, noise_dim, epochs, batch_size)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Epoch 1/100, Batch 1/25, Discriminator Loss: 3.0802645683288574, Generator Loss: 0.18077336251735687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 2/25, Discriminator Loss: 4.068397521972656, Generator Loss: 0.24791160225868225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 3/25, Discriminator Loss: 3.5802724361419678, Generator Loss: 0.324564665555954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 4/25, Discriminator Loss: 3.0116114616394043, Generator Loss: 0.40517520904541016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 5/25, Discriminator Loss: 2.577540874481201, Generator Loss: 0.4496529996395111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 6/25, Discriminator Loss: 2.2656631469726562, Generator Loss: 0.4708159863948822
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 7/25, Discriminator Loss: 2.037034273147583, Generator Loss: 0.49236276745796204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 8/25, Discriminator Loss: 1.8603450059890747, Generator Loss: 0.5096355676651001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 9/25, Discriminator Loss: 1.722428560256958, Generator Loss: 0.5235676169395447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 10/25, Discriminator Loss: 1.613633394241333, Generator Loss: 0.532589316368103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 1/100, Batch 11/25, Discriminator Loss: 1.5333049297332764, Generator Loss: 0.5392731428146362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 12/25, Discriminator Loss: 1.4667730331420898, Generator Loss: 0.5441536903381348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 13/25, Discriminator Loss: 1.4052590131759644, Generator Loss: 0.5464972853660583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 1/100, Batch 14/25, Discriminator Loss: 1.3530325889587402, Generator Loss: 0.5489677786827087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 15/25, Discriminator Loss: 1.3064820766448975, Generator Loss: 0.5524321794509888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 1/100, Batch 16/25, Discriminator Loss: 1.2625846862792969, Generator Loss: 0.5572737455368042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 1/100, Batch 17/25, Discriminator Loss: 1.2198978662490845, Generator Loss: 0.5635651350021362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Epoch 1/100, Batch 18/25, Discriminator Loss: 1.1793012619018555, Generator Loss: 0.5709233283996582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 19/25, Discriminator Loss: 1.1410679817199707, Generator Loss: 0.5785118341445923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 20/25, Discriminator Loss: 1.106344223022461, Generator Loss: 0.5836914777755737
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 21/25, Discriminator Loss: 1.091770887374878, Generator Loss: 0.584129273891449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 1/100, Batch 22/25, Discriminator Loss: 1.085205078125, Generator Loss: 0.5930351614952087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 23/25, Discriminator Loss: 1.0604043006896973, Generator Loss: 0.6014297008514404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 1/100, Batch 24/25, Discriminator Loss: 1.0329914093017578, Generator Loss: 0.6088984608650208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 1/100, Batch 25/25, Discriminator Loss: 1.0235164165496826, Generator Loss: 0.6156013607978821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 1/25, Discriminator Loss: 1.015005350112915, Generator Loss: 0.6221358776092529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 2/25, Discriminator Loss: 0.9899686574935913, Generator Loss: 0.627795934677124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 3/25, Discriminator Loss: 0.9673685431480408, Generator Loss: 0.63190096616745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 2/100, Batch 4/25, Discriminator Loss: 0.9627115726470947, Generator Loss: 0.6303551197052002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 5/25, Discriminator Loss: 0.9644631147384644, Generator Loss: 0.634652853012085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 6/25, Discriminator Loss: 0.9495434761047363, Generator Loss: 0.6386226415634155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 2/100, Batch 7/25, Discriminator Loss: 0.9307234883308411, Generator Loss: 0.6423361301422119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Epoch 2/100, Batch 8/25, Discriminator Loss: 0.9128456115722656, Generator Loss: 0.6456493139266968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Epoch 2/100, Batch 9/25, Discriminator Loss: 0.8964484333992004, Generator Loss: 0.6486330628395081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 10/25, Discriminator Loss: 0.8810540437698364, Generator Loss: 0.6516256332397461
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 11/25, Discriminator Loss: 0.8655396699905396, Generator Loss: 0.6544440984725952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 12/25, Discriminator Loss: 0.8508142232894897, Generator Loss: 0.6571729183197021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 13/25, Discriminator Loss: 0.8368735909461975, Generator Loss: 0.659839391708374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 14/25, Discriminator Loss: 0.8236207962036133, Generator Loss: 0.6624277830123901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 2/100, Batch 15/25, Discriminator Loss: 0.8110247254371643, Generator Loss: 0.6648720502853394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Epoch 2/100, Batch 16/25, Discriminator Loss: 0.7990735769271851, Generator Loss: 0.6671777367591858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 17/25, Discriminator Loss: 0.7877975702285767, Generator Loss: 0.6694069504737854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 18/25, Discriminator Loss: 0.7770543098449707, Generator Loss: 0.6715251207351685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 19/25, Discriminator Loss: 0.7675334215164185, Generator Loss: 0.6736834645271301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 20/25, Discriminator Loss: 0.7583752870559692, Generator Loss: 0.6758611798286438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 21/25, Discriminator Loss: 0.7487610578536987, Generator Loss: 0.6779922246932983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 2/100, Batch 22/25, Discriminator Loss: 0.7395437955856323, Generator Loss: 0.6800302863121033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 23/25, Discriminator Loss: 0.7307191491127014, Generator Loss: 0.681956946849823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 24/25, Discriminator Loss: 0.7223435640335083, Generator Loss: 0.6837771534919739
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 2/100, Batch 25/25, Discriminator Loss: 0.7142733335494995, Generator Loss: 0.6854948401451111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 1/25, Discriminator Loss: 0.7065141797065735, Generator Loss: 0.6870810389518738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 2/25, Discriminator Loss: 0.6990585327148438, Generator Loss: 0.6886407136917114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 3/25, Discriminator Loss: 0.6918562650680542, Generator Loss: 0.690210223197937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 4/25, Discriminator Loss: 0.6849473714828491, Generator Loss: 0.6916614770889282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 5/25, Discriminator Loss: 0.6798039674758911, Generator Loss: 0.6930411458015442
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 6/25, Discriminator Loss: 0.674879789352417, Generator Loss: 0.6946212649345398
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 3/100, Batch 7/25, Discriminator Loss: 0.6685835123062134, Generator Loss: 0.6961300373077393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 8/25, Discriminator Loss: 0.662418007850647, Generator Loss: 0.697516918182373
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 9/25, Discriminator Loss: 0.6564911007881165, Generator Loss: 0.6987577676773071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 10/25, Discriminator Loss: 0.6508119702339172, Generator Loss: 0.6998481750488281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 11/25, Discriminator Loss: 0.6453726291656494, Generator Loss: 0.7007803320884705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 12/25, Discriminator Loss: 0.6401603817939758, Generator Loss: 0.7015524506568909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 13/25, Discriminator Loss: 0.635168194770813, Generator Loss: 0.7021830081939697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 14/25, Discriminator Loss: 0.6304131746292114, Generator Loss: 0.7026394605636597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 3/100, Batch 15/25, Discriminator Loss: 0.6271717548370361, Generator Loss: 0.7031139731407166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Epoch 3/100, Batch 16/25, Discriminator Loss: 0.6240131855010986, Generator Loss: 0.7037003040313721
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 17/25, Discriminator Loss: 0.6196119785308838, Generator Loss: 0.7043551802635193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 18/25, Discriminator Loss: 0.6153031587600708, Generator Loss: 0.7050252556800842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 19/25, Discriminator Loss: 0.611113429069519, Generator Loss: 0.7056560516357422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 20/25, Discriminator Loss: 0.6070656776428223, Generator Loss: 0.7062079906463623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 21/25, Discriminator Loss: 0.6031521558761597, Generator Loss: 0.7066620588302612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 3/100, Batch 22/25, Discriminator Loss: 0.5993767380714417, Generator Loss: 0.7070357203483582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 3/100, Batch 23/25, Discriminator Loss: 0.5957367420196533, Generator Loss: 0.7073128819465637
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 24/25, Discriminator Loss: 0.5922473669052124, Generator Loss: 0.7074679732322693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 3/100, Batch 25/25, Discriminator Loss: 0.5888457298278809, Generator Loss: 0.7075641751289368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 4/100, Batch 1/25, Discriminator Loss: 0.5855181813240051, Generator Loss: 0.7076891660690308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 2/25, Discriminator Loss: 0.5822669267654419, Generator Loss: 0.7078246474266052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 3/25, Discriminator Loss: 0.5791001319885254, Generator Loss: 0.7079697251319885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 4/25, Discriminator Loss: 0.5760085582733154, Generator Loss: 0.7081366181373596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 5/25, Discriminator Loss: 0.5729779601097107, Generator Loss: 0.7083233594894409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 4/100, Batch 6/25, Discriminator Loss: 0.5700105428695679, Generator Loss: 0.7085287570953369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 7/25, Discriminator Loss: 0.5671083927154541, Generator Loss: 0.7087496519088745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 8/25, Discriminator Loss: 0.5642690658569336, Generator Loss: 0.7089830636978149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 9/25, Discriminator Loss: 0.5614932179450989, Generator Loss: 0.7092198729515076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 10/25, Discriminator Loss: 0.5587824583053589, Generator Loss: 0.709449827671051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 11/25, Discriminator Loss: 0.5561397671699524, Generator Loss: 0.7096603512763977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 12/25, Discriminator Loss: 0.5535646677017212, Generator Loss: 0.7098429203033447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 13/25, Discriminator Loss: 0.5510684847831726, Generator Loss: 0.7099997997283936
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 14/25, Discriminator Loss: 0.5486239194869995, Generator Loss: 0.7101503610610962
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 15/25, Discriminator Loss: 0.5462249517440796, Generator Loss: 0.7103089094161987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 16/25, Discriminator Loss: 0.5438648462295532, Generator Loss: 0.7104721665382385
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 17/25, Discriminator Loss: 0.5415568947792053, Generator Loss: 0.7106318473815918
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 18/25, Discriminator Loss: 0.5393019914627075, Generator Loss: 0.7107986807823181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 19/25, Discriminator Loss: 0.5370922684669495, Generator Loss: 0.7109771370887756
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 4/100, Batch 20/25, Discriminator Loss: 0.53492271900177, Generator Loss: 0.7111670970916748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 4/100, Batch 21/25, Discriminator Loss: 0.5327881574630737, Generator Loss: 0.7113711833953857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 4/100, Batch 22/25, Discriminator Loss: 0.5306857824325562, Generator Loss: 0.7115823030471802
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 4/100, Batch 23/25, Discriminator Loss: 0.5286198854446411, Generator Loss: 0.711792528629303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 4/100, Batch 24/25, Discriminator Loss: 0.5265928506851196, Generator Loss: 0.7120074033737183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 4/100, Batch 25/25, Discriminator Loss: 0.5246024131774902, Generator Loss: 0.7122297883033752
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 5/100, Batch 1/25, Discriminator Loss: 0.5226473212242126, Generator Loss: 0.7124564051628113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Epoch 5/100, Batch 2/25, Discriminator Loss: 0.5207266807556152, Generator Loss: 0.7126865983009338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 5/100, Batch 3/25, Discriminator Loss: 0.5188394784927368, Generator Loss: 0.7129196524620056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 4/25, Discriminator Loss: 0.5169845819473267, Generator Loss: 0.7131571173667908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 5/25, Discriminator Loss: 0.515160858631134, Generator Loss: 0.713398814201355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 6/25, Discriminator Loss: 0.5133674144744873, Generator Loss: 0.7136443257331848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 7/25, Discriminator Loss: 0.5116032958030701, Generator Loss: 0.7138945460319519
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 8/25, Discriminator Loss: 0.509867787361145, Generator Loss: 0.7141494154930115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 5/100, Batch 9/25, Discriminator Loss: 0.5081599950790405, Generator Loss: 0.7144087553024292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Epoch 5/100, Batch 10/25, Discriminator Loss: 0.5064792633056641, Generator Loss: 0.7146724462509155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 5/100, Batch 11/25, Discriminator Loss: 0.5048248171806335, Generator Loss: 0.7149404287338257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 12/25, Discriminator Loss: 0.5031958818435669, Generator Loss: 0.7152126431465149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 13/25, Discriminator Loss: 0.5015921592712402, Generator Loss: 0.7154889106750488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 5/100, Batch 14/25, Discriminator Loss: 0.500012993812561, Generator Loss: 0.7157692909240723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 15/25, Discriminator Loss: 0.49845778942108154, Generator Loss: 0.7160535454750061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 16/25, Discriminator Loss: 0.49692457914352417, Generator Loss: 0.7163416743278503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Epoch 5/100, Batch 17/25, Discriminator Loss: 0.49541378021240234, Generator Loss: 0.7166334986686707
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Epoch 5/100, Batch 18/25, Discriminator Loss: 0.4939247667789459, Generator Loss: 0.7169290781021118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 5/100, Batch 19/25, Discriminator Loss: 0.4924570322036743, Generator Loss: 0.7172282338142395
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 5/100, Batch 20/25, Discriminator Loss: 0.4910101890563965, Generator Loss: 0.7175309062004089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 21/25, Discriminator Loss: 0.48958343267440796, Generator Loss: 0.7178370356559753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 22/25, Discriminator Loss: 0.4881763458251953, Generator Loss: 0.718146562576294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 5/100, Batch 23/25, Discriminator Loss: 0.4867885410785675, Generator Loss: 0.7184594869613647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 5/100, Batch 24/25, Discriminator Loss: 0.485419899225235, Generator Loss: 0.7187755703926086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 5/100, Batch 25/25, Discriminator Loss: 0.48406916856765747, Generator Loss: 0.7190949320793152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 1/25, Discriminator Loss: 0.48273634910583496, Generator Loss: 0.7194173336029053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 2/25, Discriminator Loss: 0.48142099380493164, Generator Loss: 0.7197428345680237
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Epoch 6/100, Batch 3/25, Discriminator Loss: 0.4801226854324341, Generator Loss: 0.7200713157653809
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 6/100, Batch 4/25, Discriminator Loss: 0.47884124517440796, Generator Loss: 0.720402717590332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 6/100, Batch 5/25, Discriminator Loss: 0.47757601737976074, Generator Loss: 0.7207370400428772
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 6/25, Discriminator Loss: 0.4763265550136566, Generator Loss: 0.7210741639137268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Epoch 6/100, Batch 7/25, Discriminator Loss: 0.47509264945983887, Generator Loss: 0.7214140892028809
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 6/100, Batch 8/25, Discriminator Loss: 0.47387391328811646, Generator Loss: 0.7217567563056946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 6/100, Batch 9/25, Discriminator Loss: 0.4726700782775879, Generator Loss: 0.7221020460128784
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 10/25, Discriminator Loss: 0.47148075699806213, Generator Loss: 0.7224499583244324
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 11/25, Discriminator Loss: 0.4703056812286377, Generator Loss: 0.7228004932403564
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 12/25, Discriminator Loss: 0.4691444933414459, Generator Loss: 0.7231534719467163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 6/100, Batch 13/25, Discriminator Loss: 0.4679969549179077, Generator Loss: 0.7235089540481567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 6/100, Batch 14/25, Discriminator Loss: 0.46686285734176636, Generator Loss: 0.723866879940033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 15/25, Discriminator Loss: 0.4657418131828308, Generator Loss: 0.7242271900177002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 16/25, Discriminator Loss: 0.46463334560394287, Generator Loss: 0.7245898246765137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 6/100, Batch 17/25, Discriminator Loss: 0.4635373055934906, Generator Loss: 0.7249547839164734
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 18/25, Discriminator Loss: 0.46245354413986206, Generator Loss: 0.7253220081329346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 19/25, Discriminator Loss: 0.4613817632198334, Generator Loss: 0.7256914377212524
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 20/25, Discriminator Loss: 0.46032169461250305, Generator Loss: 0.7260630130767822
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 21/25, Discriminator Loss: 0.4592731297016144, Generator Loss: 0.7264367938041687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Epoch 6/100, Batch 22/25, Discriminator Loss: 0.45823580026626587, Generator Loss: 0.7268126010894775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 23/25, Discriminator Loss: 0.4572095274925232, Generator Loss: 0.7271905541419983
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 6/100, Batch 24/25, Discriminator Loss: 0.45619410276412964, Generator Loss: 0.7275704741477966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 6/100, Batch 25/25, Discriminator Loss: 0.4551892876625061, Generator Loss: 0.7279523611068726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 1/25, Discriminator Loss: 0.4541948139667511, Generator Loss: 0.7283362746238708
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 2/25, Discriminator Loss: 0.4532105326652527, Generator Loss: 0.728722095489502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 3/25, Discriminator Loss: 0.4522362947463989, Generator Loss: 0.7291097640991211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 4/25, Discriminator Loss: 0.45127183198928833, Generator Loss: 0.729499340057373
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 5/25, Discriminator Loss: 0.45031699538230896, Generator Loss: 0.729890763759613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 6/25, Discriminator Loss: 0.4493715763092041, Generator Loss: 0.7302839159965515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 7/25, Discriminator Loss: 0.4484354853630066, Generator Loss: 0.7306788563728333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 8/25, Discriminator Loss: 0.44750839471817017, Generator Loss: 0.7310755848884583
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 9/25, Discriminator Loss: 0.44659027457237244, Generator Loss: 0.731473982334137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 10/25, Discriminator Loss: 0.4456808865070343, Generator Loss: 0.7318741083145142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 11/25, Discriminator Loss: 0.4447800815105438, Generator Loss: 0.7322758436203003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 7/100, Batch 12/25, Discriminator Loss: 0.44388771057128906, Generator Loss: 0.7326791882514954
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 7/100, Batch 13/25, Discriminator Loss: 0.44300365447998047, Generator Loss: 0.7330842018127441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 14/25, Discriminator Loss: 0.4421278238296509, Generator Loss: 0.7334907054901123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 15/25, Discriminator Loss: 0.4412599205970764, Generator Loss: 0.7338988184928894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 16/25, Discriminator Loss: 0.4403998553752899, Generator Loss: 0.7343084216117859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 7/100, Batch 17/25, Discriminator Loss: 0.43954747915267944, Generator Loss: 0.7347195744514465
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 18/25, Discriminator Loss: 0.43870270252227783, Generator Loss: 0.735132098197937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 19/25, Discriminator Loss: 0.43786537647247314, Generator Loss: 0.7355461716651917
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 20/25, Discriminator Loss: 0.4370354115962982, Generator Loss: 0.7359616160392761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 21/25, Discriminator Loss: 0.43621259927749634, Generator Loss: 0.7363784909248352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 22/25, Discriminator Loss: 0.43539687991142273, Generator Loss: 0.7367967367172241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 7/100, Batch 23/25, Discriminator Loss: 0.43458813428878784, Generator Loss: 0.7372163534164429
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 7/100, Batch 24/25, Discriminator Loss: 0.4337862730026245, Generator Loss: 0.7376373410224915
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 7/100, Batch 25/25, Discriminator Loss: 0.432991087436676, Generator Loss: 0.7380595803260803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 8/100, Batch 1/25, Discriminator Loss: 0.4322025179862976, Generator Loss: 0.738483190536499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 2/25, Discriminator Loss: 0.4314204752445221, Generator Loss: 0.7389079928398132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 3/25, Discriminator Loss: 0.43064481019973755, Generator Loss: 0.7393341064453125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 4/25, Discriminator Loss: 0.4298754632472992, Generator Loss: 0.7397614121437073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 5/25, Discriminator Loss: 0.4291123151779175, Generator Loss: 0.7401899695396423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Epoch 8/100, Batch 6/25, Discriminator Loss: 0.42835524678230286, Generator Loss: 0.7406197190284729
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 7/25, Discriminator Loss: 0.42760419845581055, Generator Loss: 0.741050660610199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 8/100, Batch 8/25, Discriminator Loss: 0.426859050989151, Generator Loss: 0.741482675075531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 9/25, Discriminator Loss: 0.42611968517303467, Generator Loss: 0.7419158816337585
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 8/100, Batch 10/25, Discriminator Loss: 0.42538610100746155, Generator Loss: 0.7423502206802368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 11/25, Discriminator Loss: 0.4246581196784973, Generator Loss: 0.7427856922149658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Epoch 8/100, Batch 12/25, Discriminator Loss: 0.4239357113838196, Generator Loss: 0.7432222366333008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 13/25, Discriminator Loss: 0.4232187271118164, Generator Loss: 0.7436597943305969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 14/25, Discriminator Loss: 0.42250722646713257, Generator Loss: 0.7440984845161438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 15/25, Discriminator Loss: 0.42180100083351135, Generator Loss: 0.7445381283760071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 8/100, Batch 16/25, Discriminator Loss: 0.4210999608039856, Generator Loss: 0.7449789047241211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 17/25, Discriminator Loss: 0.4204040765762329, Generator Loss: 0.7454206347465515
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 18/25, Discriminator Loss: 0.41971322894096375, Generator Loss: 0.7458632588386536
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 19/25, Discriminator Loss: 0.4190273880958557, Generator Loss: 0.7463069558143616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 20/25, Discriminator Loss: 0.4183465242385864, Generator Loss: 0.746751606464386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 8/100, Batch 21/25, Discriminator Loss: 0.41767048835754395, Generator Loss: 0.747197151184082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 22/25, Discriminator Loss: 0.4169992208480835, Generator Loss: 0.7476436495780945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 8/100, Batch 23/25, Discriminator Loss: 0.4163326621055603, Generator Loss: 0.7480910420417786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 24/25, Discriminator Loss: 0.4156707525253296, Generator Loss: 0.7485392689704895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 8/100, Batch 25/25, Discriminator Loss: 0.4150134325027466, Generator Loss: 0.7489885091781616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 1/25, Discriminator Loss: 0.4143606126308441, Generator Loss: 0.7494385242462158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 2/25, Discriminator Loss: 0.4137122631072998, Generator Loss: 0.7498894333839417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 3/25, Discriminator Loss: 0.41306832432746887, Generator Loss: 0.7503411769866943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 9/100, Batch 4/25, Discriminator Loss: 0.41242867708206177, Generator Loss: 0.7507937550544739
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 9/100, Batch 5/25, Discriminator Loss: 0.4117933213710785, Generator Loss: 0.7512471079826355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 6/25, Discriminator Loss: 0.4111621379852295, Generator Loss: 0.751701295375824
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 7/25, Discriminator Loss: 0.41053515672683716, Generator Loss: 0.7521562576293945
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 8/25, Discriminator Loss: 0.4099122881889343, Generator Loss: 0.7526120543479919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 9/25, Discriminator Loss: 0.4092934727668762, Generator Loss: 0.7530685663223267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 10/25, Discriminator Loss: 0.4086786210536957, Generator Loss: 0.7535257935523987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 11/25, Discriminator Loss: 0.4080677032470703, Generator Loss: 0.7539837956428528
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 12/25, Discriminator Loss: 0.40746068954467773, Generator Loss: 0.7544424533843994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 13/25, Discriminator Loss: 0.40685755014419556, Generator Loss: 0.7549018859863281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 14/25, Discriminator Loss: 0.40625816583633423, Generator Loss: 0.7553619742393494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 15/25, Discriminator Loss: 0.40566253662109375, Generator Loss: 0.7558227777481079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 16/25, Discriminator Loss: 0.40507060289382935, Generator Loss: 0.756284236907959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 17/25, Discriminator Loss: 0.40448230504989624, Generator Loss: 0.7567463517189026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 18/25, Discriminator Loss: 0.40389758348464966, Generator Loss: 0.7572091221809387
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 19/25, Discriminator Loss: 0.4033163785934448, Generator Loss: 0.7576726078987122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 20/25, Discriminator Loss: 0.4027387499809265, Generator Loss: 0.7581366896629333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 9/100, Batch 21/25, Discriminator Loss: 0.4021645784378052, Generator Loss: 0.7586014270782471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 9/100, Batch 22/25, Discriminator Loss: 0.4015938341617584, Generator Loss: 0.7590667009353638
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 23/25, Discriminator Loss: 0.40102648735046387, Generator Loss: 0.7595325708389282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 24/25, Discriminator Loss: 0.40046241879463196, Generator Loss: 0.7599990963935852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 9/100, Batch 25/25, Discriminator Loss: 0.39990168809890747, Generator Loss: 0.7604660987854004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 1/25, Discriminator Loss: 0.39934417605400085, Generator Loss: 0.7609337568283081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 2/25, Discriminator Loss: 0.3987899422645569, Generator Loss: 0.761401891708374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 3/25, Discriminator Loss: 0.3982388377189636, Generator Loss: 0.7618706226348877
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 4/25, Discriminator Loss: 0.39769089221954346, Generator Loss: 0.7623398303985596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 5/25, Discriminator Loss: 0.3971460461616516, Generator Loss: 0.7628096342086792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 6/25, Discriminator Loss: 0.3966042995452881, Generator Loss: 0.763279914855957
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 7/25, Discriminator Loss: 0.3960655927658081, Generator Loss: 0.7637507319450378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 8/25, Discriminator Loss: 0.3955298662185669, Generator Loss: 0.7642220258712769
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 9/25, Discriminator Loss: 0.3949970602989197, Generator Loss: 0.7646937966346741
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Epoch 10/100, Batch 10/25, Discriminator Loss: 0.39446723461151123, Generator Loss: 0.7651660442352295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 11/25, Discriminator Loss: 0.3939403295516968, Generator Loss: 0.7656387686729431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 12/25, Discriminator Loss: 0.39341628551483154, Generator Loss: 0.7661119699478149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 13/25, Discriminator Loss: 0.39289504289627075, Generator Loss: 0.766585648059845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 14/25, Discriminator Loss: 0.3923766016960144, Generator Loss: 0.7670597434043884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 15/25, Discriminator Loss: 0.3918609619140625, Generator Loss: 0.7675343155860901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Epoch 10/100, Batch 16/25, Discriminator Loss: 0.39134806394577026, Generator Loss: 0.7680092453956604
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Epoch 10/100, Batch 17/25, Discriminator Loss: 0.3908378481864929, Generator Loss: 0.7684845924377441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 18/25, Discriminator Loss: 0.39033031463623047, Generator Loss: 0.7689603567123413
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 19/25, Discriminator Loss: 0.38982540369033813, Generator Loss: 0.7694364786148071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 20/25, Discriminator Loss: 0.3893231749534607, Generator Loss: 0.7699130177497864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 21/25, Discriminator Loss: 0.3888235092163086, Generator Loss: 0.770389974117279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Epoch 10/100, Batch 22/25, Discriminator Loss: 0.3883264362812042, Generator Loss: 0.7708672881126404
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 23/25, Discriminator Loss: 0.3878318667411804, Generator Loss: 0.7713449597358704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 10/100, Batch 24/25, Discriminator Loss: 0.38733983039855957, Generator Loss: 0.771822988986969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 10/100, Batch 25/25, Discriminator Loss: 0.3868502676486969, Generator Loss: 0.7723013758659363
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 11/100, Batch 1/25, Discriminator Loss: 0.38636314868927, Generator Loss: 0.7727801203727722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 11/100, Batch 2/25, Discriminator Loss: 0.3858785033226013, Generator Loss: 0.7732591032981873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Epoch 11/100, Batch 3/25, Discriminator Loss: 0.38539624214172363, Generator Loss: 0.7737385034561157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Epoch 11/100, Batch 4/25, Discriminator Loss: 0.38491636514663696, Generator Loss: 0.7742182016372681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Epoch 11/100, Batch 5/25, Discriminator Loss: 0.3844388723373413, Generator Loss: 0.7746982574462891
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Epoch 11/100, Batch 6/25, Discriminator Loss: 0.3839637041091919, Generator Loss: 0.7751785516738892
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
